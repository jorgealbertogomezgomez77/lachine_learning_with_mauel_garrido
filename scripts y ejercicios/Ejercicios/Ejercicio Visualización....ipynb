# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/datasets/Curso_Mauel_Garrido/datos-misteriosos.csv")
df.head()
# Out:
#   dataset        x        y
# 0  clase1  55.3846  97.1795
# 1  clase1  51.5385  96.0256
# 2  clase1  46.1538  94.4872
# 3  clase1  42.8205  91.4103
# 4  clase1  40.7692  88.3333

# %%
# %matplotlib notebook
plt.scatter(df.x, df.y, marker = "*", color = "red")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("X vs Y")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'X vs Y')

# %%
df.dataset.unique()
# Out:
# array(['clase1', 'clase2'], dtype=object)

# %%
df[df.dataset == "clase1"].plot.scatter(x = "x", y = "y")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df[df.dataset == "clase2"].plot.scatter(x = "x", y = "y")
# Out:
# <img src="data:image/png;base64,..." width="640">
