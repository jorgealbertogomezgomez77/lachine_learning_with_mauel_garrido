# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [100, 150, 150, 200, 250, 300, 325, 400, 415, 500, 600, 1000]

# %%
np.std(x)
# Out:
# 239.6771555423856

# %%
plt.hist(x)
# Out:
# (array([3., 2., 2., 2., 1., 1., 0., 0., 0., 1.]),
#  array([ 100.,  190.,  280.,  370.,  460.,  550.,  640.,  730.,  820.,
#          910., 1000.]),
#  <a list of 10 Patch objects>)

# %%
# Get this figure: fig = py.get_figure("https://plot.ly/~matlab_user_guide/661/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~matlab_user_guide/661/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="matlab_overview_1", fileopt="extend")
# Get y data of first trace: y1 = py.get_figure("https://plot.ly/~matlab_user_guide/661/").get_data()[0]["y"]

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('JorgeAlbertoGomezGomez', 'sh5SW9OwBGO70J8Xgcrs')
trace1 = {
  "x": [1.0, 1.090909, 1.181818, 1.272727, 1.363636, 1.454545, 1.545455, 1.636364, 1.727273, 1.818182, 1.909091, 2.0, 2.090909, 2.181818, 2.272727, 2.363636, 2.454545, 2.545455, 2.636364, 2.727273, 2.818182, 2.909091, 3.0, 3.090909, 3.181818, 3.272727, 3.363636, 3.454545, 3.545455, 3.636364, 3.727273, 3.818182, 3.909091, 4.0, 4.090909, 4.181818, 4.272727, 4.363636, 4.454545, 4.545455, 4.636364, 4.727273, 4.818182, 4.909091, 5.0, 5.090909, 5.181818, 5.272727, 5.363636, 5.454545, 5.545455, 5.636364, 5.727273, 5.818182, 5.909091, 6.0, 6.090909, 6.181818, 6.272727, 6.363636, 6.454545, 6.545455, 6.636364, 6.727273, 6.818182, 6.909091, 7.0, 7.090909, 7.181818, 7.272727, 7.363636, 7.454545, 7.545455, 7.636364, 7.727273, 7.818182, 7.909091, 8.0, 8.090909, 8.181818, 8.272727, 8.363636, 8.454545, 8.545455, 8.636364, 8.727273, 8.818182, 8.909091, 9.0, 9.090909, 9.181818, 9.272727, 9.363636, 9.454545, 9.545455, 9.636364, 9.727273, 9.818182, 9.909091, 10.0], 
  "y": [-1.204389, -0.653498, -1.116509, -0.601011, -0.181427, -1.005939, -0.656085, 0.097125, -0.123995, -0.230738, 0.610392, 0.54837, 0.082785, 0.343516, 0.622337, 0.729959, 1.514326, 2.193422, 0.69978, 0.861911, 1.196493, 2.377012, 2.129531, 1.546109, 2.238781, 2.261544, 2.843831, 2.482686, 1.918559, 2.114071, 1.598611, 2.303448, 1.644782, 2.72152, 2.008895, 2.210847, 2.201748, 1.985511, 1.269674, 1.253156, 1.479545, 1.915088, 1.406139, 0.248208, 1.618468, 0
  "line": {
    "color": "rgb(255,0,0)", 
    "dash": "dash", 
    "width": 2.0
  }, 
  "mode": "lines", 
  "showlegend": False, 
  "type": "scatter", 
  "visible": True, 
  "xaxis": "x", 
  "yaxis": "y"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "autosize": False, 
  "height": 630.0, 
  "legend": {
    "x": 0.142411, 
    "y": 0.907738, 
    "bgcolor": "rgb(255,255,255)", 
    "bordercolor": "rgb(0,0,0)", 
    "borderwidth": 0.5, 
    "xanchor": "left", 
    "yanchor": "top"
  }, 
  "margin": {
    "r": 73.8, 
    "t": 80.0, 
    "b": 47.2, 
    "l": 73.8, 
    "pad": 0.0
  }, 
  "showlegend": True, 
  "width": 840.0, 
  "xaxis": {
    "anchor": "y", 
    "autotick": False, 
    "domain": [0.13, 0.905], 
    "dtick": 1.0, 
    "linecolor": "rgb(0,0,0)", 
    "mirror": False, 
    "range": [1.0, 10.0], 
    "showgrid": False, 
    "showline": True, 
    "side": "bottom", 
    "tick0": 1.0, 
    "tickcolor": "rgb(0,0,0)", 
    "tickfont": {
      "color": "rgb(0,0,0)", 
      "size": 10.0
    }, 
    "ticklen": 6.51, 
    "ticks": "inside", 
    "title": "X", 
    "titlefont": {
      "color": "rgb(0,0,0)", 
      "size": 13.0
    }, 
    "type": "linear", 
    "zeroline": False
  }, 
  "yaxis": {
    "anchor": "x", 
    "autotick": False, 
    "domain": [0.11, 1.0], 
    "dtick": 1.0, 
    "linecolor": "rgb(0,0,0)", 
    "mirror": False, 
    "range": [-2.0, 5.0], 
    "showgrid": False, 
    "showline": True, 
    "side": "left", 
    "tick0": -2.0, 
    "tickcolor": "rgb(0,0,0)", 
    "tickfont": {
      "color": "rgb(0,0,0)", 
      "size": 10.0
    }, 
    "ticklen": 6.51, 
    "ticks": "inside", 
    "title": "Noisy", 
    "titlefont": {
      "color": "rgb(0,0,0)", 
      "size": 13.0
    }, 
    "type": "linear", 
    "zeroline": False
  }
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig)
# Out:
# c:\users\jorge\appdata\local\programs\python\python37\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4a4b0a833f09> in <module>
#     156   }
#     157 }
# --> 158 fig = Figure(data=data, layout=layout)
#     159 plot_url = py.plot(fig)
#
# c:\users\jorge\appdata\local\programs\python\python37\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid)
#     469             is invalid AND skip_invalid is False
#     470         """
# ...
